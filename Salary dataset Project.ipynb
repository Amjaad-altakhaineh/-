# %% [markdown]
# [Download Dataset](https://www.kaggle.com/kaggle/sf-salaries)

# %% [markdown]
# # SF Salaries
# ## Explore San Francisco city employee salary data
#
#
# One way to understand how a city government works is by looking at who it employs and how its employees are compensated. This data contains the names, job title, and compensation for San Francisco city employees on an annual basis from 2011 to 2014.
#
# (opens in a new tab)">salary distribution
#
# Exploration Ideas
# To help get you started, here are some data exploration ideas:
#
# How have salaries changed over time between different groups of people?
# How are base pay, overtime pay, and benefits allocated between different groups?
# Is there any evidence of pay discrimination based on gender in this dataset?
# How is budget allocated based on different groups and responsibilities?
# Have other ideas you're curious for someone else to explore? Post them in this forum thread.
#
# Data Description
# sf-salaries-release-*.zip (downloadable via the "Download Data" link in the header above) contains a CSV table and a SQLite database (with the same data as the CSV file). Here's the code that creates this data release.
#
# The original source for this data is here. We've taken the raw files here and combined/normalized them into a single CSV file as well as a SQLite database with an equivalently-defined table.

# %% [markdown]
# Please excuse anything that doesn't make "Real-World" sense in the dataframe,
#
# Also note that all of these questions can be answered with one line of code.
# ____
# ###  Import pandas and read in the salary dataset csv file and set it to a DataFrame called ecom. **

# %%
import pandas as pd 
import numpy as np

df=pd.read_csv("Salary dataset.csv")
# Out:
# C:\Users\Odai For Computer\AppData\Local\Temp\ipykernel_40688\641073643.py:4: DtypeWarning: Columns (3,4,5,6,7,8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("Salary dataset.csv")

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43        567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28        538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91        335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61        332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19        326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# 1  2011    NaN  San Francisco    NaN
# 2  2011    NaN  San Francisco    NaN
# 3  2011    NaN  San Francisco    NaN
# 4  2011    NaN  San Francisco    NaN

# %% [markdown]
# ### 1.Display Top 10 Rows of The Dataset

# %%
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43        567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28        538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91        335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61        332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19        326373.19
# 5   118602.0      8601.0  189082.74      NaN  316285.74        316285.74
# 6   92492.01     89062.9  134426.14      NaN  315981.05        315981.05
# 7  256576.96         0.0    51322.5      NaN  307899.46        307899.46
# 8  176932.64    86362.68   40132.23      NaN  303427.55        303427.55
# 9   285262.0         0.0   17115.73      NaN  302377.73        302377.73
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# 1  2011    NaN  San Francisco    NaN
# 2  2011    NaN  San Francisco    NaN
# 3  2011    NaN  San Francisco    NaN
# 4  2011    NaN  San Francisco    NaN
# 5  2011    NaN  San Francisco    NaN
# 6  2011    NaN  San Francisco    NaN
# 7  2011    NaN  San Francisco    NaN
# 8  2011    NaN  San Francisco    NaN
# 9  2011    NaN  San Francisco    NaN

# %% [markdown]
# ### 2. Check Last 10 Rows of The Dataset

# %%
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant             0
# 148645  148646  Carolyn A Wilson     Human Services Technician             0
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2             0
# 148648  148649       Leon Walker                     Custodian             0
# 148649  148650     Roy I Tillery                     Custodian             0
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay      Benefits TotalPay TotalPayBenefits  \
# 148644             0             0             0      0.0              0.0
# 148645             0             0             0      0.0              0.0
# 148646  Not Provided  Not Provided  Not Provided      0.0              0.0
# 148647             0             0             0      0.0              0.0
# 148648             0             0             0      0.0              0.0
# 148649             0             0             0      0.0              0.0
# 148650  Not Provided  Not Provided  Not Provided      0.0              0.0
# 148651  Not Provided  Not Provided  Not Provided      0.0              0.0
# 148652  Not Provided  Not Provided  Not Provided      0.0              0.0
# 148653             0       -618.13             0  -618.13          -618.13
#
#         Year  Notes         Agency Status
# 148644  2014    NaN  San Francisco     PT
# 148645  2014    NaN  San Francisco     PT
# 148646  2014    NaN  San Francisco    NaN
# 148647  2014    NaN  San Francisco     PT
# 148648  2014    NaN  San Francisco     PT
# 148649  2014    NaN  San Francisco     PT
# 148650  2014    NaN  San Francisco    NaN
# 148651  2014    NaN  San Francisco    NaN
# 148652  2014    NaN  San Francisco    NaN
# 148653  2014    NaN  San Francisco     PT

# %% [markdown]
# ### 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
df.shape
# Out:
# (148654, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  object
#  8   TotalPayBenefits  148654 non-null  object
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 14.7+ MB

# %% [markdown]
# ### 4. Getting Information About Our Dataset Like Total Number Rows,
# ### Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  object
#  8   TotalPayBenefits  148654 non-null  object
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 14.7+ MB

# %% [markdown]
# ### 5.Check Null Values In The Dataset

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# ### 6. Drop ID, Notes, Agency and Status Columns

# %%
df.drop(columns=["Id", "Notes", "Agency", "Status"], inplace=True)

# %%
df
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# 0          167411.18           0.0     400184.25           NaN  567595.43
# 1          155966.02     245131.88     137811.38           NaN  538909.28
# 2          212739.13     106088.18       16452.6           NaN  335279.91
# 3            77916.0      56120.71      198306.9           NaN  332343.61
# 4           134401.6        9737.0     182234.59           NaN  326373.19
# ...              ...           ...           ...           ...        ...
# 148649             0             0             0             0        0.0
# 148650  Not Provided  Not Provided  Not Provided  Not Provided        0.0
# 148651  Not Provided  Not Provided  Not Provided  Not Provided        0.0
# 148652  Not Provided  Not Provided  Not Provided  Not Provided        0.0
# 148653             0             0       -618.13             0    -618.13
#
#        TotalPayBenefits  Year
# 0             567595.43  2011
# 1             538909.28  2011
# 2             335279.91  2011
# 3             332343.61  2011
# 4             326373.19  2011
# ...                 ...   ...
# 148649              0.0  2014
# 148650              0.0  2014
# 148651              0.0  2014
# 148652              0.0  2014
# 148653          -618.13  2014
#
# [148654 rows x 9 columns]

# %% [markdown]
# ### 7. Get Overall Statistics About The Dataframe

# %%
df_filled.describe(include="all")
# Out:
#        EmployeeName          JobTitle        BasePay    OvertimePay  \
# count        148654            148654  148654.000000  148654.000000
# unique       110811              2159            NaN            NaN
# top       Kevin Lee  Transit Operator            NaN            NaN
# freq             13              7036            NaN            NaN
# mean            NaN               NaN   66052.883956    5065.923568
# std             NaN               NaN   42886.774672   11454.256594
# min             NaN               NaN    -166.010000      -0.010000
# 25%             NaN               NaN   32791.507500       0.000000
# 50%             NaN               NaN   64860.615000       0.000000
# 75%             NaN               NaN   94605.345000    4657.632500
# max             NaN               NaN  319275.010000  245131.880000
#
#              OtherPay       Benefits       TotalPay  TotalPayBenefits  \
# count   148654.000000  148654.000000  148654.000000     148654.000000
# unique            NaN            NaN            NaN               NaN
# top               NaN            NaN            NaN               NaN
# freq              NaN            NaN            NaN               NaN
# mean      3648.669115   18924.232839   74756.743508      93691.378617
# std       8056.515703   17165.279495   50518.951240      62793.650910
# min      -7058.590000     -33.890000    -618.130000       -618.130000
# 25%          0.000000       0.000000   36138.505000      44063.330000
# 50%        811.170000   23214.020000   71417.030000      92401.805000
# 75%       4235.907500   33468.980000  105825.895000     132876.060000
# max     400184.250000   96570.660000  567595.430000     567595.430000
#
#                  Year
# count   148654.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean      2012.522643
# std          1.117538
# min       2011.000000
# 25%       2012.000000
# 50%       2013.000000
# 75%       2014.000000
# max       2014.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   EmployeeName      148654 non-null  object
#  1   JobTitle          148654 non-null  object
#  2   BasePay           148049 non-null  object
#  3   OvertimePay       148654 non-null  object
#  4   OtherPay          148654 non-null  object
#  5   Benefits          112495 non-null  object
#  6   TotalPay          148654 non-null  object
#  7   TotalPayBenefits  148654 non-null  object
#  8   Year              148654 non-null  int64
# dtypes: int64(1), object(8)
# memory usage: 10.2+ MB

# %%
columns_to_convert = ['BasePay', 'OvertimePay', 'OtherPay', 'Benefits', 'TotalPay', 'TotalPayBenefits']
df[columns_to_convert] = df[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   EmployeeName      148654 non-null  object
#  1   JobTitle          148654 non-null  object
#  2   BasePay           148044 non-null  float64
#  3   OvertimePay       148650 non-null  float64
#  4   OtherPay          148650 non-null  float64
#  5   Benefits          112491 non-null  float64
#  6   TotalPay          148641 non-null  float64
#  7   TotalPayBenefits  148653 non-null  float64
#  8   Year              148654 non-null  int64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 10.2+ MB

# %%
df_filled = df.fillna({'BasePay': 0,"OvertimePay":0, "OtherPay":0, "Benefits":0, "TotalPay":0,"TotalPayBenefits":0,"EmployeeName":"Unknown","JobTitle":"Unknown" })

# %%
df_filled
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# 0       167411.18         0.00  400184.25       0.0  567595.43
# 1       155966.02    245131.88  137811.38       0.0  538909.28
# 2       212739.13    106088.18   16452.60       0.0  335279.91
# 3        77916.00     56120.71  198306.90       0.0  332343.61
# 4       134401.60      9737.00  182234.59       0.0  326373.19
# ...           ...          ...        ...       ...        ...
# 148649       0.00         0.00       0.00       0.0       0.00
# 148650       0.00         0.00       0.00       0.0       0.00
# 148651       0.00         0.00       0.00       0.0       0.00
# 148652       0.00         0.00       0.00       0.0       0.00
# 148653       0.00         0.00    -618.13       0.0    -618.13
#
#         TotalPayBenefits  Year
# 0              567595.43  2011
# 1              538909.28  2011
# 2              335279.91  2011
# 3              332343.61  2011
# 4              326373.19  2011
# ...                  ...   ...
# 148649              0.00  2014
# 148650              0.00  2014
# 148651              0.00  2014
# 148652              0.00  2014
# 148653           -618.13  2014
#
# [148654 rows x 9 columns]

# %% [markdown]
# ### 8. Find Occurrence of The Employee Names  (Top 5)

# %%
df["EmployeeName"].value_counts().head(5)
# Out:
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: EmployeeName, dtype: int64

# %% [markdown]
# ### 9. Find The Number of Unique Job Titles

# %%
df["JobTitle"].nunique()
# Out:
# 2159

# %%
ca=[]
for i in range(0,len(df["JobTitle"])):
    H=df["JobTitle"][i]
    
    if "Captain" in H:
        ca.append(H)
        
len(ca)
# Out:
# 411

# %%
ca
# Out:
# ['Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Emergency Med Svcs',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Emergency Med Svcs',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  "Sheriff's Captain",
#  'Captain, Emergency Med Svcs',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  "Sheriff's Captain",
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  "Sheriff's Captain",
#  "Sheriff's Captain",
#  'Captain, Fire Suppression',
#  "Sheriff's Captain",
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  "Sheriff's Captain",
#  "Sheriff's Captain",
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Emergency Med Svcs',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Emergency Med Svcs',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  "Sheriff's Captain",
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  "Sheriff's Captain",
#  "Sheriff's Captain",
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  "Sheriff's Captain",
#  'Captain, Fire Suppression',
#  "Sheriff's Captain",
#  "Sheriff's Captain",
#  "Sheriff's Captain",
#  "Sheriff's Captain",
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, (Fire Department)',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Emergency Med Svcs',
#  'Captain, Emergency Med Svcs',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Emergency Med Svcs',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain 3',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Emergency Med Svcs',
#  'Captain 3',
#  'Captain, Emergency Med Svcs',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  "Sheriff's Captain",
#  'Captain, Fire Suppression',
#  "Sheriff's Captain",
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  "Sheriff's Captain",
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  "Sheriff's Captain",
#  'Captain, Emergency Med Svcs',
#  "Sheriff's Captain",
#  "Sheriff's Captain",
#  'Captain, Emergency Med Svcs',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  'Captain, Emergency Med Svcs',
#  "Sheriff's Captain",
#  'Captain, Fire Suppression',
#  'Captain, Emergency Med Svcs',
#  "Sheriff's Captain",
#  'Captain, Emergency Med Svcs',
#  'Captain, Emergency Med Svcs',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression',
#  'Captain 3',
#  'Captain, Fire Suppression']

# %%
df[df['JobTitle'].str.contains('Captain', na=False)].shape[0]
# Out:
# 411

# %% [markdown]
# ### 10. Total Number of Job Titles Contain Captain

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   EmployeeName      148654 non-null  object
#  1   JobTitle          148654 non-null  object
#  2   BasePay           148049 non-null  object
#  3   OvertimePay       148654 non-null  object
#  4   OtherPay          148654 non-null  object
#  5   Benefits          112495 non-null  object
#  6   TotalPay          148654 non-null  object
#  7   TotalPayBenefits  148654 non-null  object
#  8   Year              148654 non-null  int64
# dtypes: int64(1), object(8)
# memory usage: 10.2+ MB

# %% [markdown]
# ### 11. Display All the Employee Names From Fire Department

# %%
df[df['JobTitle'].str.contains('Fire Department', na=False)]["EmployeeName"]

# %%
v
# Out:
# Series([], Name: EmployeeName, dtype: object)

# %% [markdown]
# ### 12. Find Minimum, Maximum and Average BasePay

# %%
df["BasePay"].max()
# Out:
# 319275.01

# %%
df['BasePay'] = df['BasePay'].abs()

# %%
df["BasePay"].min()
# Out:
# 0.0

# %% [markdown]
# ### 13. Replace 'Not Provided' in EmployeeName' Column to NaN

# %%
df_filled["EmployeeName"].replace("Not provided", np.NaN, inplace=True)

# %%
df_filled
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650                NaN                                    Not provided
# 148651                NaN                                    Not provided
# 148652                NaN                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# 0       167411.18         0.00  400184.25       0.0  567595.43
# 1       155966.02    245131.88  137811.38       0.0  538909.28
# 2       212739.13    106088.18   16452.60       0.0  335279.91
# 3        77916.00     56120.71  198306.90       0.0  332343.61
# 4       134401.60      9737.00  182234.59       0.0  326373.19
# ...           ...          ...        ...       ...        ...
# 148649       0.00         0.00       0.00       0.0       0.00
# 148650       0.00         0.00       0.00       0.0       0.00
# 148651       0.00         0.00       0.00       0.0       0.00
# 148652       0.00         0.00       0.00       0.0       0.00
# 148653       0.00         0.00    -618.13       0.0    -618.13
#
#         TotalPayBenefits  Year
# 0              567595.43  2011
# 1              538909.28  2011
# 2              335279.91  2011
# 3              332343.61  2011
# 4              326373.19  2011
# ...                  ...   ...
# 148649              0.00  2014
# 148650              0.00  2014
# 148651              0.00  2014
# 148652              0.00  2014
# 148653           -618.13  2014
#
# [148654 rows x 9 columns]

# %% [markdown]
# ### 15. Find Job Title of ALBERT PARDINI

# %%
df_filled[df_filled["EmployeeName"]=="ALBERT PARDINI"]["JobTitle"]
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
df_filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   EmployeeName      148648 non-null  object
#  1   JobTitle          148654 non-null  object
#  2   BasePay           148654 non-null  float64
#  3   OvertimePay       148654 non-null  float64
#  4   OtherPay          148654 non-null  float64
#  5   Benefits          148654 non-null  float64
#  6   TotalPay          148654 non-null  float64
#  7   TotalPayBenefits  148654 non-null  float64
#  8   Year              148654 non-null  int64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 10.2+ MB

# %% [markdown]
# ### 16. How Much ALBERT PARDINI Make (Include Benefits) ?

# %%
df_filled[df_filled["EmployeeName"]=="ALBERT PARDINI"]["TotalPayBenefits"]
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %%
filtered_rows = df[df['EmployeeName'] == 'ALBERT PARDINI']

# %%
filtered_rows
# Out:
#      EmployeeName                         JobTitle    BasePay  OvertimePay  \
# 2  ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
#
#    OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# 2   16452.6       NaN  335279.91         335279.91  2011

# %% [markdown]
# ### 17. Display Name of The Person Having The Highest BasePay

# %%
filtered_rows = df[df['BasePay'] == df['BasePay'].max() ]

# %%
filtered_rows
# Out:
#          EmployeeName         JobTitle    BasePay  OvertimePay  OtherPay  \
# 72925  Gregory P Suhr  Chief of Police  319275.01          0.0  20007.06
#
#        Benefits   TotalPay  TotalPayBenefits  Year
# 72925  86533.21  339282.07         425815.28  2013

# %% [markdown]
# ### 18. Find Average BasePay of All Employee Per Year

# %% [markdown]
# ### 19. Find Average BasePay of All Employee Per JobTitle

# %% [markdown]
# ### 20. Find Average BasePay of Employee Having Job Title ACCOUNTANT

# %% [markdown]
# ### 21. Find Top 5 Most Common Jobs
